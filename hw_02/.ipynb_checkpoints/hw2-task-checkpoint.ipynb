# %% [markdown]
# # SkillFactory
# ## Введение в ML, введение в sklearn

# %% [markdown]
# В этом задании мы с вами рассмотрим данные с конкурса [Задача предсказания отклика клиентов ОТП Банка](http://www.machinelearning.ru/wiki/index.php?title=%D0%97%D0%B0%D0%B4%D0%B0%D1%87%D0%B0_%D0%BF%D1%80%D0%B5%D0%B4%D1%81%D0%BA%D0%B0%D0%B7%D0%B0%D0%BD%D0%B8%D1%8F_%D0%BE%D1%82%D0%BA%D0%BB%D0%B8%D0%BA%D0%B0_%D0%BA%D0%BB%D0%B8%D0%B5%D0%BD%D1%82%D0%BE%D0%B2_%D0%9E%D0%A2%D0%9F_%D0%91%D0%B0%D0%BD%D0%BA%D0%B0_%28%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%29)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12,5)

# %% [markdown]
# ### Грузим данные

# %% [markdown]
# Считаем описание данных

# %%
df_descr = pd.read_csv('data/otp_description.csv', sep='\t', encoding='utf8')

# %%
df_descr
# Out:
#                           ПОЛЕ  \
# 0                 AGREEMENT_RK
# 1                          AGE
# 2            SOCSTATUS_WORK_FL
# 3            SOCSTATUS_PENS_FL
# 4                       GENDER
# 5                  CHILD_TOTAL
# 6                   DEPENDANTS
# 7                    EDUCATION
# 8               MARITAL_STATUS
# 9                 GEN_INDUSTRY
# 10                   GEN_TITLE
# 11                ORG_TP_STATE
# 12             ORG_TP_FCAPITAL
# 13                     JOB_DIR
# 14               FAMILY_INCOME
# 15             PERSONAL_INCOME
# 16        REG_ADDRESS_PROVINCE
# 17       FACT_ADDRESS_PROVINCE
# 18     POSTAL_ADDRESS_PROVINCE
# 19                 TP_PROVINCE
# 20                   REGION_NM
# 21                 REG_FACT_FL
# 22                FACT_POST_FL
# 23                 REG_POST_FL
# 24            REG_FACT_POST_FL
# 25         REG_FACT_POST_TP_FL
# 26              FL_PRESENCE_FL
# 27                    OWN_AUTO
# 28                 AUTO_RUS_FL
# 29              HS_PRESENCE_FL
# 30             COT_PRESENCE_FL
# 31             GAR_PRESENCE_FL
# 32            LAND_PRESENCE_FL
# 33                      CREDIT
# 34                        TERM
# 35                 FST_PAYMENT
# 36              DL_DOCUMENT_FL
# 37             GPF_DOCUMENT_FL
# 38            FACT_LIVING_TERM
# 39                   WORK_TIME
# 40               FACT_PHONE_FL
# 41                REG_PHONE_FL
# 42                GEN_PHONE_FL
# 43              LOAN_NUM_TOTAL
# 44             LOAN_NUM_CLOSED
# 45               LOAN_NUM_PAYM
# 46                LOAN_DLQ_NUM
# 47                LOAN_MAX_DLQ
# 48            LOAN_AVG_DLQ_AMT
# 49            LOAN_MAX_DLQ_AMT
# 50  PREVIOUS_CARD_NUM_UTILIZED
#
#                                              ОПИСАНИЕ
# 0          уникальный идентификатор объекта в выборке
# 1                                     возраст клиента
# 2   социальный статус клиента относительно работы ...
# 3   социальный статус клиента относительно пенсии ...
# 4                 пол клиента (1- женщины, 0-мужчины)
# 5                            количество детей клиента
# 6                       количество иждивенцев клиента
# 7                                         образование
# 8                                  семейное положение
# 9                              отрасль работы клиента
# 10                                          должность
# 11                       форма собственности компании
# 12                  отношение к иностранному капиталу
# 13          направление деятельности в нутри компании
# 14               семейный доход (несколько категорий)
# 15                    личный доход клиента (в рублях)
# 16                        область регистрации клиента
# 17            область фактического пребывания клиента
# 18                             почтовый адрес область
# 19  область торговой точки, где клиент брал послед...
# 20                                          регион РФ
# 21  адрес регистрации и адрес фактического пребыва...
# 22  адрес фактического пребывания клиента и его по...
# 23  адрес регистрации клиента и его почтовый адрес...
# 24  почтовый, фактический и адрес регистрации совп...
# 25  область регистрации, фактического пребывания, ...
# 26  наличие в собственности квартиры (1 - есть, 0 ...
# 27                кол-во автомобилей в собственности
# 28  наличие в собственности автомобиля российского...
# 29  наличие в собственности загородного дома (1 - ...
# 30  наличие в собственности котеджа (1 - есть, 0 -...
# 31  наличие в собственности гаража (1 - есть, 0 - ...
# 32  наличие в собственности земельного участка (1 ...
# 33        сумма последнего кредита клиента (в рублях)
# 34                                       срок кредита
# 35                    первоначальный взнос (в рублях)
# 36  в анкете клиент указал водительское удостовере...
# 37  в анкете клиен указал ГПФ (1 - указал, 0 - не ...
# 38  количество месяцев проживания по месту фактиче...
# 39          время работы на текущем месте (в месяцах)
# 40  наличие в заявке телефона по фактическому мест...
# 41     наличие в заявке телефона по месту регистрации
# 42                 наличие в заявке рабочего телефона
# 43                            количество ссуд клиента
# 44                 количество погашенных ссуд клиента
# 45         количество платежей, которые сделал клиент
# 46          количество просрочек, допущенных клиентом
# 47  номер максимальной просрочки, допущенной клиентом
# 48                 средняя сумма просрочки (в рублях)
# 49            максимальная сумма просрочки (в рублях)
# 50  количество уже утилизированных карт ( если пус...

# %% [markdown]
# Считаем обучающую выборки и тестовую (которую мы как бы не видим)

# %%
df_train = pd.read_csv('data/otp_train.csv', sep='\t', encoding='utf8')

# %%
df_train.shape
# Out:
# (15223, 52)

# %%
df_test = pd.read_csv('data/otp_test.csv', sep='\t', encoding='utf8')

# %%
df_test.shape
# Out:
# (14910, 52)

# %%
df_train.head()
# Out:
#    AGREEMENT_RK  TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 0      59910150       0   49                  1                  0       1
# 1      59910230       0   32                  1                  0       1
# 2      59910525       0   52                  1                  0       1
# 3      59910803       0   39                  1                  0       1
# 4      59911781       0   30                  1                  0       0
#
#    CHILD_TOTAL  DEPENDANTS            EDUCATION  MARITAL_STATUS  \
# 0            2           1  Среднее специальное  Состою в браке
# 1            3           3              Среднее  Состою в браке
# 2            4           0     Неполное среднее  Состою в браке
# 3            1           1               Высшее  Состою в браке
# 4            0           0              Среднее  Состою в браке
#
#              ...             REG_PHONE_FL GEN_PHONE_FL LOAN_NUM_TOTAL  \
# 0            ...                        0            1              1
# 1            ...                        0            1              1
# 2            ...                        0            1              2
# 3            ...                        1            1              1
# 4            ...                        0            1              2
#
#   LOAN_NUM_CLOSED LOAN_NUM_PAYM LOAN_DLQ_NUM LOAN_MAX_DLQ  LOAN_AVG_DLQ_AMT  \
# 0               1             6            2            1              1580
# 1               1             6            1            1              4020
# 2               1            11            0            0                 0
# 3               1             6            3            1  1589,92333333333
# 4               1            16            2            1           1152,15
#
#   LOAN_MAX_DLQ_AMT PREVIOUS_CARD_NUM_UTILIZED
# 0             1580                        NaN
# 1             4020                        NaN
# 2                0                        NaN
# 3             1590                        NaN
# 4             2230                        NaN
#
# [5 rows x 52 columns]

# %% [markdown]
# ## Объединим две выборки
#
# Так как пока мы пока не умеем работать sklearn  Pipeline, то для того, чтобы после предобработки столбцы в двух выборках находились на своих местах.
#
# Для того, чтобы в дальнейшем отделить их введем новый столбец "sample"

# %%
df_train.loc[:, 'sample'] = 'train'
df_test.loc[:, 'sample'] = 'test'

# %%
df = df_test.append(df_train).reset_index(drop=True)

# %%
df.shape
# Out:
# (30133, 53)

# %% [markdown]
# ### Чуть-чуть посмотрим на данные

# %% [markdown]
# Посмотрим типы данных и их заполняемость

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Data columns (total 53 columns):
# AGREEMENT_RK                  30133 non-null int64
# TARGET                        30133 non-null int64
# AGE                           30133 non-null int64
# SOCSTATUS_WORK_FL             30133 non-null int64
# SOCSTATUS_PENS_FL             30133 non-null int64
# GENDER                        30133 non-null int64
# CHILD_TOTAL                   30133 non-null int64
# DEPENDANTS                    30133 non-null int64
# EDUCATION                     30133 non-null object
# MARITAL_STATUS                30133 non-null object
# GEN_INDUSTRY                  27420 non-null object
# GEN_TITLE                     27420 non-null object
# ORG_TP_STATE                  27420 non-null object
# ORG_TP_FCAPITAL               27425 non-null object
# JOB_DIR                       27420 non-null object
# FAMILY_INCOME                 30133 non-null object
# PERSONAL_INCOME               30133 non-null object
# REG_ADDRESS_PROVINCE          30133 non-null object
# FACT_ADDRESS_PROVINCE         30133 non-null object
# POSTAL_ADDRESS_PROVINCE       30133 non-null object
# TP_PROVINCE                   29543 non-null object
# REGION_NM                     30131 non-null object
# REG_FACT_FL                   30133 non-null int64
# FACT_POST_FL                  30133 non-null int64
# REG_POST_FL                   30133 non-null int64
# REG_FACT_POST_FL              30133 non-null int64
# REG_FACT_POST_TP_FL           30133 non-null int64
# FL_PRESENCE_FL                30133 non-null int64
# OWN_AUTO                      30133 non-null int64
# AUTO_RUS_FL                   30133 non-null int64
# HS_PRESENCE_FL                30133 non-null int64
# COT_PRESENCE_FL               30133 non-null int64
# GAR_PRESENCE_FL               30133 non-null int64
# LAND_PRESENCE_FL              30133 non-null int64
# CREDIT                        30133 non-null object
# TERM                          30133 non-null int64
# FST_PAYMENT                   30133 non-null object
# DL_DOCUMENT_FL                30133 non-null int64
# GPF_DOCUMENT_FL               30133 non-null int64
# FACT_LIVING_TERM              30133 non-null int64
# WORK_TIME                     27416 non-null float64
# FACT_PHONE_FL                 30133 non-null int64
# REG_PHONE_FL                  30133 non-null int64
# GEN_PHONE_FL                  30133 non-null int64
# LOAN_NUM_TOTAL                30133 non-null int64
# LOAN_NUM_CLOSED               30133 non-null int64
# LOAN_NUM_PAYM                 30133 non-null int64
# LOAN_DLQ_NUM                  30133 non-null int64
# LOAN_MAX_DLQ                  30133 non-null int64
# LOAN_AVG_DLQ_AMT              30133 non-null object
# LOAN_MAX_DLQ_AMT              30133 non-null object
# PREVIOUS_CARD_NUM_UTILIZED    600 non-null float64
# sample                        30133 non-null object
# dtypes: float64(2), int64(32), object(19)
# memory usage: 12.2+ MB

# %% [markdown]
# Видим, что часть данных - object, скорее всего стоки.
#
#
# Давайте выведем эти значения для каждого столбца

# %%
for i in df_train.columns: # перебираем все столбцы
    if str(df_train[i].dtype) == 'object': # если тип столбца - object
        print('='*10)
        print(i) # выводим название столбца
        print(set(df_train[i])) # выводим все его значения (но делаем set - чтоб значения не повторялись)
        print('\n') # выводим пустую строку
# Out:
# ==========
# EDUCATION
# {'Среднее', 'Неполное среднее', 'Неоконченное высшее', 'Ученая степень', 'Высшее', 'Среднее специальное', 'Два и более высших образования'}
#
#
# ==========
# MARITAL_STATUS
# {'Разведен(а)', 'Состою в браке', 'Гражданский брак', 'Не состоял в браке', 'Вдовец/Вдова'}
#
#
# ==========
# GEN_INDUSTRY
# {nan, 'Строительство', 'Сельское хозяйство', 'Нефтегазовая промышленность', 'Недвижимость', 'Банк/Финансы', 'Энергетика', 'Развлечения/Искусство', 'Наука', 'Страхование', 'Информационные услуги', 'Логистика', 'Салоны красоты и здоровья', 'Туризм', 'Государственная служба', 'Управляющая компания', 'Другие сферы', 'Коммунальное хоз-во/Дорожные службы', 'Торговля', 'Сборочные производства', 'ЧОП/Детективная д-ть', 'Транспорт', 'Юридические услуги/нотариальные услуги', 'Химия/Парфюмерия/Фармацевтика', 'Здравоохранение', 'Подбор персонала', 'Маркетинг', 'Образование', 'Информационные технологии', 'СМИ/Реклама/PR-агенства', 'Металлургия/Промышленность/Машиностроение', 'Ресторанный бизнес/Общественное питание'}
#
#
# ==========
# GEN_TITLE
# {nan, 'Рабочий', 'Военнослужащий по контракту', 'Руководитель низшего звена', 'Специалист', 'Другое', 'Руководитель среднего звена', 'Индивидуальный предприниматель', 'Служащий', 'Работник сферы услуг', 'Партнер', 'Высококвалифиц. специалист', 'Руководитель высшего звена'}
#
#
# ==========
# ORG_TP_STATE
# {nan, 'Государственная комп./учреж.', 'Некоммерческая организация', 'Индивидуальный предприниматель', 'Частная ком. с инос. капиталом', 'Частная компания'}
#
#
# ==========
# ORG_TP_FCAPITAL
# {nan, 'С участием', 'Без участия'}
#
#
# ==========
# JOB_DIR
# {nan, 'Кадровая служба и секретариат', 'Адм-хоз. и трансп. службы', 'Бухгалтерия, финансы, планир.', 'Служба безопасности', 'Юридическая служба', 'Вспомогательный техперсонал', 'Пр-техн. обесп. и телеком.', 'Реклама и маркетинг', 'Участие в основ. деятельности', 'Снабжение и сбыт'}
#
#
# ==========
# FAMILY_INCOME
# {'от 20000 до 50000 руб.', 'свыше 50000 руб.', 'от 10000 до 20000 руб.', 'от 5000 до 10000 руб.', 'до 5000 руб.'}
#
#
# ==========
# PERSONAL_INCOME
# {'7300', '6800', '5800', '48000', '11600', '4700', '45000', '8600', '17000', '40000', '22500', '4600', '3400', '21500', '4900', '3000', '17700', '3500', '4590', '28000', '12300', '12500', '29000', '5350', '7101', '33000', '14800', '24500', '14700', '13150', '2800', '30000', '7250', '15560', '9500', '10100', '11000', '12650', '4300', '26500', '21800', '6600', '17404', '5000', '13300', '10700', '13160', '7640', '9600', '8700', '3700', '11300', '52000', '15300', '3600', '6500', '11200', '5680', '11800', '19000', '13200', '7400', '220000', '19700', '14000', '3100', '8066', '9900', '11700', '14358', '9800', '4400', '12400', '17800', '7550', '67700', '11400', '16200', '12900', '6700', '75000', '15600', '150000', '7050', '5425', '9700', '15400', '6100', '5360', '23500', '1950', '67000', '47000', '5100', '60000', '10900', '5339', '110000', '6608', '42000', '25000', '17500', '54000', '9330', '250000', '16000', '77000', '17600', '8350', '24800', '9400', '5300', '10400', '12800', '23800', '2300', '12700', '13450', '26000', '39000', '9000', '6299,19', '6900', '6300', '4800', '32000', '55000', '24000', '16100', '20000', '5582', '18500', '16700', '7251', '12100', '18200', '13600', '5200', '13800', '18700', '10000', '16050', '28300', '8726', '5900', '16900', '7220', '51000', '4330', '7850', '49000', '22955', '5600', '19800', '35000', '8500', '23100', '92000', '4360', '9240', '160000', '7830', '8000', '15000', '42500', '20646,16', '19300', '8800', '17900', '9628', '5230', '18600', '3800', '27300', '80000', '4000', '68000', '5700', '17200', '10800', '6180', '36000', '10600', '53000', '41000', '11900', '13400', '5500', '13500', '4950', '70000', '18000', '6359', '15200', '13900', '37000', '14500', '6000', '4500', '29500', '5050', '2000', '11640', '22000', '50000', '65000', '9100', '7900', '8400', '2100', '34000', '20500', '9300', '11500', '6200', '10500', '6670', '100000', '10200', '43000', '46000', '12000', '13000', '170000', '7600', '25800', '8300', '7500', '9200', '19500', '41900', '16500', '7800', '5446', '4200', '9340', '13700', '10300', '27000', '32640', '3900', '3300', '7100', '21000', '5790', '4100', '14300', '5400', '38000', '23000', '4340', '15380', '16800', '3200', '6400', '29800', '7650', '19600', '7000', '5088', '24', '44000', '56000', '8900', '7700', '8200', '5460', '31000', '8250', '7200', '12600', '15500', '8100', '4515'}
#
#
# ==========
# REG_ADDRESS_PROVINCE
# {'Ивановская область', 'Калужская область', 'Тульская область', 'Ленинградская область', 'Белгородская область', 'Удмуртия', 'Свердловская область', 'Коми', 'Усть-Ордынский Бурятский АО', 'Бурятия', 'Ярославская область', 'Приморский край', 'Северная Осетия', 'Якутия', 'Кабардино-Балкария', 'Псковская область', 'Астраханская область', 'Курганская область', 'Краснодарский край', 'Ямало-Ненецкий АО', 'Архангельская область', 'Орловская область', 'Тюменская область', 'Агинский Бурятский АО', 'Горный Алтай', 'Хакасия', 'Магаданская область', 'Тверская область', 'Пензенская область', 'Сахалинская область', 'Чувашия', 'Смоленская область', 'Московская область', 'Новгородская область', 'Калмыкия', 'Амурская область', 'Карелия', 'Хабаровский край', 'Адыгея', 'Алтайский край', 'Костромская область', 'Еврейская АО', 'Волгоградская область', 'Ростовская область', 'Липецкая область', 'Оренбургская область', 'Вологодская область', 'Воронежская область', 'Курская область', 'Ульяновская область', 'Рязанская область', 'Москва', 'Эвенкийский АО', 'Нижегородская область', 'Татарстан', 'Дагестан', 'Новосибирская область', 'Санкт-Петербург', 'Калининградская область', 'Читинская область', 'Тамбовская область', 'Карачаево-Черкесия', 'Иркутская область', 'Мордовская республика', 'Мурманская область', 'Томская область', 'Красноярский край', 'Кемеровская область', 'Камчатская область', 'Башкирия', 'Ханты-Мансийский АО', 'Ставропольский край', 'Владимирская область', 'Омская область', 'Саратовская область', 'Пермская область', 'Кировская область', 'Брянская область', 'Челябинская область', 'Марийская республика', 'Самарская область'}
#
#
# ==========
# FACT_ADDRESS_PROVINCE
# {'Ивановская область', 'Калужская область', 'Тульская область', 'Ленинградская область', 'Белгородская область', 'Удмуртия', 'Свердловская область', 'Коми', 'Усть-Ордынский Бурятский АО', 'Бурятия', 'Ярославская область', 'Приморский край', 'Северная Осетия', 'Якутия', 'Кабардино-Балкария', 'Псковская область', 'Астраханская область', 'Курганская область', 'Краснодарский край', 'Ямало-Ненецкий АО', 'Архангельская область', 'Орловская область', 'Тюменская область', 'Агинский Бурятский АО', 'Горный Алтай', 'Хакасия', 'Магаданская область', 'Тверская область', 'Пензенская область', 'Сахалинская область', 'Чувашия', 'Смоленская область', 'Московская область', 'Новгородская область', 'Калмыкия', 'Амурская область', 'Карелия', 'Хабаровский край', 'Адыгея', 'Алтайский край', 'Костромская область', 'Еврейская АО', 'Волгоградская область', 'Ростовская область', 'Липецкая область', 'Оренбургская область', 'Вологодская область', 'Воронежская область', 'Курская область', 'Ульяновская область', 'Рязанская область', 'Москва', 'Эвенкийский АО', 'Нижегородская область', 'Татарстан', 'Дагестан', 'Новосибирская область', 'Санкт-Петербург', 'Калининградская область', 'Читинская область', 'Тамбовская область', 'Карачаево-Черкесия', 'Иркутская область', 'Мордовская республика', 'Мурманская область', 'Томская область', 'Красноярский край', 'Кемеровская область', 'Камчатская область', 'Башкирия', 'Ханты-Мансийский АО', 'Ставропольский край', 'Владимирская область', 'Омская область', 'Саратовская область', 'Пермская область', 'Кировская область', 'Брянская область', 'Челябинская область', 'Марийская республика', 'Самарская область'}
#
#
# ==========
# POSTAL_ADDRESS_PROVINCE
# {'Ивановская область', 'Калужская область', 'Тульская область', 'Ленинградская область', 'Белгородская область', 'Удмуртия', 'Свердловская область', 'Коми', 'Усть-Ордынский Бурятский АО', 'Бурятия', 'Ярославская область', 'Приморский край', 'Северная Осетия', 'Якутия', 'Кабардино-Балкария', 'Псковская область', 'Астраханская область', 'Курганская область', 'Краснодарский край', 'Ямало-Ненецкий АО', 'Архангельская область', 'Орловская область', 'Тюменская область', 'Агинский Бурятский АО', 'Горный Алтай', 'Хакасия', 'Магаданская область', 'Тверская область', 'Пензенская область', 'Сахалинская область', 'Чувашия', 'Смоленская область', 'Московская область', 'Новгородская область', 'Калмыкия', 'Амурская область', 'Карелия', 'Хабаровский край', 'Адыгея', 'Алтайский край', 'Костромская область', 'Еврейская АО', 'Волгоградская область', 'Ростовская область', 'Липецкая область', 'Оренбургская область', 'Вологодская область', 'Воронежская область', 'Курская область', 'Ульяновская область', 'Рязанская область', 'Москва', 'Эвенкийский АО', 'Нижегородская область', 'Татарстан', 'Новосибирская область', 'Санкт-Петербург', 'Калининградская область', 'Читинская область', 'Тамбовская область', 'Карачаево-Черкесия', 'Иркутская область', 'Мордовская республика', 'Мурманская область', 'Томская область', 'Красноярский край', 'Кемеровская область', 'Камчатская область', 'Башкирия', 'Ханты-Мансийский АО', 'Ставропольский край', 'Владимирская область', 'Омская область', 'Саратовская область', 'Пермская область', 'Кировская область', 'Брянская область', 'Челябинская область', 'Марийская республика', 'Самарская область'}
#
#
# ==========
# TP_PROVINCE
# {'Ивановская область', 'Калужская область', nan, 'Тульская область', 'Белгородская область', 'Удмуртия', 'Свердловская область', 'Коми', 'Бурятия', 'Ярославская область', 'Приморский край', 'Якутия', 'Курганская область', 'Псковская область', 'Астраханская область', 'Кабардино-Балкария', 'Краснодарский край', 'Архангельская область', 'Орловская область', 'Тюменская область', 'Горный Алтай', 'Магаданская область', 'Тверская область', 'Пензенская область', 'Сахалинская область', 'Чувашия', 'Смоленская область', 'Новгородская область', 'Амурская область', 'Карелия', 'Хабаровский край', 'Адыгея', 'Алтайский край', 'Костромская область', 'Еврейская АО', 'Волгоградская область', 'Ростовская область', 'Липецкая область', 'Оренбургская область', 'Вологодская область', 'Воронежская область', 'Курская область', 'Ульяновская область', 'Рязанская область', 'Москва', 'Нижегородская область', 'Татарстан', 'Новосибирская область', 'Санкт-Петербург', 'Калининградская область', 'Читинская область', 'Тамбовская область', 'Иркутская область', 'Мордовская республика', 'Мурманская область', 'Томская область', 'Красноярский край', 'Ставропольский край', 'Камчатская область', 'Кемеровская область', 'Башкирия', 'Ханты-Мансийский АО', 'Владимирская область', 'Омская область', 'Саратовская область', 'Пермская область', 'Кировская область', 'Брянская область', 'Челябинская область', 'Марийская республика', 'Самарская область'}
35', '2080', '2820', '1221,92', '5048,19', '1176,82', '1102,7', '2503,19', '2755,21', '1200,99', '2902,89', '446,31', '1418,86', '1470', '1029,75', '2500', '570', '1508,79', '115,65', '599,19', '3240', '2549,52', '2202,69', '1870', '883,33', '2732,2', '1819,09', '2064,08', '2960', '3780,1', '4650', '2840', '663,05', '2163,94', '918,28', '3600', '3510', '2477,64', '1010,27', '586,5', '0', '965,1', '1050', '400', '499,69', '1880,59', '1317,06', '1130', '1920', '3100', '1828,89', '481,51', '776,6', '1540', '4190', '1266,34', '3910', '1530', '724,38', '4400', '2702,4', '605,59', '3970', '1370,25', '1138,2', '1539,2', '869,26', '1296,74', '3490', '1883,04', '2360', '1479,51', '1402,43', '6390', '772,73', '2140', '4260', '3810', '370', '560,36', '1411,31', '2920', '1240', '1387,3', '4550', '812,11', '791,98', '2524,28', '2600', '658,42', '918,55', '1095,61', '3590', '2084,32', '5550', '289,02', '2900', '3630', '490,88', '6080', '62,46', '1649,37', '849,91', '1820', '1966,99', '3780', '3890', '2850', '1365', '2950', '1580', '1959,99', '2060', '680', '1258,49', '5320', '1931,44', '1371,86', '4055,03', '2699,88', '1538,69', '1670,18', '4030', '1837,31', '610', '110,91', '478,13', '1110', '440', '1740', '1819,26', '1851,55', '1090,01', '2480', '1260', '620,75', '3120', '490', '367', '1789,04', '3420', '1310', '5872,64', '875,09', '2005,15', '1910', '5580', '430', '4620', '1068,47', '2510', '1288,63', '5075,99', '4310', '3260', '1086,57', '3520', '840,4', '1010', '1360', '3660', '1319,56', '2497', '1672,88', '1970', '2509,38', '28012,2', '1439,94', '6490', '804,32', '1890', '2160', '553', '3637,43', '860', '904, ...
#
#
# ==========
# sample
# {'train'}

# %% [markdown]
# Mожно заметить что некоторые переменные, которые обозначены как строки (например PERSONAL_INCOME) на самом деле числа, но по какой-то причине были распознаны как строки
#
# Причина же что использовалась запятая для разделения не целой части числа..

# %% [markdown]
# Перекодировать их можно например так:

# %%
df['PERSONAL_INCOME'].map(lambda x: x.replace(',', '.')).astype('float')
# Out:
# 0         7000.0
# 1         4100.0
# 2        40000.0
# 3        20000.0
# 4        17000.0
# 5         7000.0
# 6        10000.0
# 7         7500.0
# 8         9000.0
# 9         4000.0
# 10       15000.0
# 11       12000.0
# 12        8000.0
# 13       20000.0
# 14       18500.0
# 15       14000.0
# 16        6000.0
# 17        9000.0
# 18        5000.0
# 19       15000.0
# 20        6100.0
# 21       22180.0
# 22        9000.0
# 23        8700.0
# 24        7000.0
# 25        6000.0
# 26       15000.0
# 27       12000.0
# 28       11000.0
# 29        8000.0
#           ...
# 30103    12000.0
# 30104    10000.0
# 30105    10000.0
# 30106     8000.0
# 30107    11000.0
# 30108     7000.0
# 30109    10000.0
# 30110     8000.0
# 30111    25000.0
# 30112    10000.0
# 30113    12000.0
# 30114     7000.0
# 30115    12000.0
# 30116    14500.0
# 30117    12000.0
# 30118     8000.0
# 30119     7000.0
# 30120    10000.0
# 30121    10000.0
# 30122    10000.0
# 30123    15000.0
# 30124     8100.0
# 30125     9500.0
# 30126    13000.0
# 30127    10000.0
# 30128    12000.0
# 30129    10000.0
# 30130     6000.0
# 30131     4500.0
# 30132    20000.0
# Name: PERSONAL_INCOME, Length: 30133, dtype: float64

# %% [markdown]
# Такой эффект наблюдается в столбцах `PERSONAL_INCOME`, `CREDIT`, `FST_PAYMENT`, `LOAN_AVG_DLQ_AMT`, `LOAN_MAX_DLQ_AMT`

# %% [markdown]
# ### Теперь ваше небольшое исследование

# %% [markdown]
# #### Задание 1. Есть ли пропуски в данных? Что с ними сделать?
#
# (единственного верного ответа нет - аргументируйте)

# %% [markdown]
# #### Задание 2. Есть ли категориальные признаки? Что с ними делать?

# %% [markdown]
# #### Задание 3. Фунция предобработки

# %% [markdown]
# Напишите функцию, которая бы
#
# * Удаляло идентификатор `AGREEMENT_RK`
# * Избавлялась от проблем с '.' и ',' в стобцах PERSONAL_INCOME, CREDIT, FST_PAYMENT, LOAN_AVG_DLQ_AMT, LOAN_MAX_DLQ_AMT
# * Что-то делала с пропусками
# * Кодировала категориальные признаки
#
# В результате, ваш датафрейм должен содержать только числа и не содержать пропусков!

# %%
def preproc_data(df_input):
    df_output = df_input.copy()
    
    
    ## Your Code Here
    
    return df_output

# %%
df_preproc = df.pipe(preproc_data)

df_train_preproc = df_preproc.query('sample == "train"').drop(['sample'], axis=1)
df_test_preproc = df_preproc.query('sample == "test"').drop(['sample'], axis=1)

# %% [markdown]
# #### Задание 4. Отделите целевую переменную и остальные признаки
#
# Должно получится:
# * 2 матрицы: X и X_test
# * 2 вектора: y и y_test

# %% [markdown]
# #### Задание 5. Обучение и оценка качества разных моделей

# %%
from sklearn.cross_validation import train_test_split
# test_size=0.3, random_state=42

## Your Code Here

# %%
# Попробовать следующие "черные ящики": интерфейс одинаковый 
# Постепенно мы узнаем, что они делают а сейчас учимся понимать какой работает качественнее
#     fit, 
#     predict, 
#     predict_proba

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

## Your Code Here

# %%
# Посчитать метрики стандартные
# accuracy, precision, recall

from sklearn.metrics import accuracy_score, precision_score, recall_score

## Your Code Here

# %%
# Визуалищировать эти метрики всех моделей на одном графике (чтоб визуально сравнить)
# Возможно вас удивит качество! Но задача подобрана специально ;) Такое качество тоже бывает

## Your Code Here

# %%
# Потроить roc-кривые всех можелей на одном графике
# Вывести roc_auc каждой моделе
# Подпишите оси и линии

## Your Code Here

# %%
from sklearn.cross_validation import cross_val_score
# Сделать k-fold (10 фолдов) кросс-валидацию каждой модели
# И посчитать средний roc_auc

## Your Code Here

# %%
# Взять лучшую модель и сделать предсказания (с вероятностями (!!!)) для test выборки

predict = 
## Your Code Here

# %%
# Померить roc_auc на тесте
# Вывести текстом и на графике =)

## Your Code Here

# %% [markdown]
# ### Больше обязательных заданий нет, но ниже вы можете провести исследование, поиграться с данными
# ### Это возможность написать код, который я посмотрю и в случае чего откомметирую. ;)
# ### Это не оценивается и остается на ваше усмотрение. Просто дополнительная возможность

# %%
### И далее ;)
